# %%
''' @Author: Subhadeep Bej'''
# Out:
# ' @Author: Subhadeep Bej'

# %%
# Installing necessary packages

# ! pip install matplotlib scipy

# %% [markdown]
# ## Probability density at t=0

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
plt.style.use("ggplot")

# %%
import scipy.constants as const
import math
import numpy as np

# %%
pi = const.pi
hbar = const.hbar

# %%
p2 = 10**(-34)        # Some random value
p1 = 0.8*10**(-34)

# %%
x = np.linspace(-50, 50, 1000)

# %%
rho = [2/(pi*(hbar**2)) * (math.cos(((p1 - p2)*x)/(2*hbar)))**2 for x in x]  # at t = 0

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(x, rho);
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
ax.set_xlabel("x");

# %%
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

# %%
# ax.set_xlim(-30, 30)

# %%
ax.tick_params(labelleft=False, left=False)

# %%
ax.set_yticklabels([]);

# %%
ax.set_title("Probability distribution at t = 0");

# %% [markdown]
# ## Time evolution

# %%
# %%latex
#
# $$
#
#  {\Large   \rho(x) = \frac{2}{\pi\hbar} cos^2(\frac{P_2-P_1}{2\hbar}x - \frac{E_2-E_1}{2\hbar}t) }\\
#
# $$
# Out:
# $$
#
#  {\Large   \rho(x) = \frac{2}{\pi\hbar} cos^2(\frac{P_2-P_1}{2\hbar}x - \frac{E_2-E_1}{2\hbar}t) }\\
#
# $$

# %%
E1 = 10**(-34)
E2 = 0.8*E1

# %%
from matplotlib import animation

# %%
n = 2000
def update(curr):
    curr = curr*10
    if curr == n:
        a.event_source.stop()
    t = curr / 100
    plt.cla()
    rho_ = [2/(pi*(hbar**2)) * math.cos((((p1 - p2)*x)/(2*hbar)) + (((E1 - E2)*t)/(2*hbar)))**2 for x in x]
    plt.plot(x, rho_)
    plt.gcf().subplots_adjust(bottom=0.15)
    plt.gca().set(yticklabels=[])
    plt.gca().tick_params(left=False)
    plt.gca().set_xlabel("X")
    plt.gca().set_title("Time evolution of probability density")
    plt.annotate(s = f"t = {t}s", xy = (0.9, 0.9), xycoords="figure fraction", fontsize=10)
    plt.annotate(s = 'Visualisation by Subhadeep Bej', xy=(0.1, 0.9), xycoords='figure fraction', fontsize=8,
                 color='xkcd:slate', alpha=0.8)

# %%
fig = plt.figure(figsize=(9, 3.5))
a = animation.FuncAnimation(fig, update, interval=50)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
a.save("probability_density_animation.avi")          # Saving the animation as a mp4 file

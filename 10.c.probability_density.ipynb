# %%
'''@Author: Subhadeep Bej'''

# %%
import matplotlib.pyplot as plt
import math 
import numpy as np
import scipy.constants as const

# %%
pi = const.pi
hbar = const.hbar

# %%
# %matplotlib notebook
plt.style.use('ggplot')

# %%
x = np.linspace(-30, 30, 600)

# %%
d = 10**(-34)
m2 = 10**(-2)  # m squared
t = 1

# %%
# rho  = [(d/(np.sqrt(2*pi))) * 1/(np.sqrt(((d/hbar)**4) + ((t**2) / (4*m2*(hbar)**2)))) * np.exp(  (-(4 * (d**2)* (x**2))) / 
#                                                      ((4*(d**4)) + (((t**2)*(hbar**2))/m2))   ) for x in x]

# %%
rho  = [(  1/np.sqrt(1 + ((t**2) / (4*m2*(hbar**2)))))*np.exp(  (-(4 * (d**2)* (x**2))) / ((4*(d**4)) + (((t**2)*(hbar**2))/m2))   ) for x in x]

# %%
fig, ax = plt.subplots()
ax.plot(x, rho)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.get_ylim()
# Out:
# (-1.0544766623373619e-36, 2.2144009909088655e-35)

# %%
from matplotlib import animation

# %%
n = 1200

def update(curr):
    curr  = curr * 5
    if curr == n:
        a.event_source.stop()
    plt.cla()
    t = curr / 60
    rho  = [(  1/np.sqrt(1 + ((t**2) / (4*m2*(hbar**2)))))*np.exp(  (-(4 * (d**2)* (x**2))) / ((4*(d**4)) + (((t**2)*(hbar**2))/m2))   ) for x in x]
    plt.plot(x, rho, lw=2)
    plt.gca().set_ylim(-1.0544763619e-36, 2.2144009955e-35)
    
    plt.gca().set_title("Time evolution of probability density")
    plt.gca().set_xlabel("X")
    plt.gca().set(yticklabels=[])
    plt.gca().tick_params(left=False)
    plt.gca().fill_between(x, rho, facecolor = '#e76f51', alpha=0.6)
    plt.annotate(s = f"t ={t:0.2f}s", xy=(0.9,0.9), xycoords='figure fraction', fontsize=10)
    plt.annotate(s = 'Visualization by Subhadeep Bej', xy=(0.05,0.9), xycoords='figure fraction', fontsize=8,
                      color='xkcd:slate', alpha=0.8)

# %%
fig = plt.figure(figsize=(8, 5.8))
a = animation.FuncAnimation(fig, update, interval=50, frames=250, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
a.save('probability_density_fixed_yscale.mp4', fps=24, extra_args=['-vcodec', 'libx264'])
